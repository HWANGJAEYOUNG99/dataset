# %% [markdown]
# # **1. 기존 프로젝트 코드 실행**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import sklearn
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.model_selection import train_test_split, cross_val_score  # cross_validation을 model_selection으로 변경-  과거 버전 코드로 실행 오류 발생하여 코드 수정
import matplotlib
matplotlib.style.use('seaborn')
# %matplotlib inline
# Out:
# <ipython-input-1-f7e671c971bc>:13: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   matplotlib.style.use('seaborn')

# %%
df = pd.read_csv('/content/drive/MyDrive/2024_인공지능/팀플_타이타닉/train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test = pd.read_csv('/content/drive/MyDrive/2024_인공지능/팀플_타이타닉/test.csv')
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %% [markdown]
# ### Exploration

# %%
# SibSp: number of siblings and spouses traveling with
# Parch: number of parents and children traveling with
# The embarkation : It has three possible values S,C,Q
df['Age'].fillna(df['Age'].median(), inplace=True)
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.361582    0.523008
# std     257.353842    0.486592    0.836071   13.019697    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
sns.countplot(x= 'Sex', hue='Survived', data=df)
plt.title("Women and children first !")
# Out:
# Text(0.5, 1.0, 'Women and children first !')

# %%
figure = plt.figure(figsize=(17,8))
plt.hist([df[df['Survived']==1]['Age'], df[df['Survived']==0]['Age']], stacked=True, color = ['g','r'],
         bins = 30, label = ['Survived','Dead'])
plt.xlabel('Age')
plt.ylabel('Number of passengers')
plt.legend()
plt.title("Women and children first !")
# Out:
# Text(0.5, 1.0, 'Women and children first !')

# %%
figure = plt.figure(figsize=(15,8))
plt.hist([df[df['Survived']==1]['Fare'],
          df[df['Survived']==0]['Fare']], color = ['g','r'],
         bins = 30,label = ['Survived','Dead'])
plt.xlabel('Fare')
plt.xlim([0,300])
plt.ylabel('Number of passengers')
plt.legend()

# %%
plt.figure(figsize=(15,8))
ax = plt.subplot()
ax.scatter(df[df['Survived']==1]['Age'],df[df['Survived']==1]['Fare'], c='green',s=40)
ax.scatter(df[df['Survived']==0]['Age'],df[df['Survived']==0]['Fare'], c='red',s=40)
ax.set_xlabel('Age')
ax.set_ylabel('Fare')
ax.set_ylim([0,300])
ax.legend(('survived','dead'),scatterpoints=1,loc='upper right',fontsize=15,)

# %%
sns.countplot(x= 'Embarked', hue='Survived', data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# ### Feature Engineering

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
train = pd.read_csv('/content/drive/MyDrive/2024_인공지능/팀플_타이타닉/train.csv')
test = pd.read_csv('/content/drive/MyDrive/2024_인공지능/팀플_타이타닉/test.csv')
targets = train.Survived
train.drop('Survived', axis=1, inplace=True)
combined = pd.concat([train, test])
combined.reset_index(inplace=True)
combined.drop('index', inplace=True, axis=1)

# %%
# Extracting title from the names
Title_Dictionary = {"Capt":       "Officer",
                    "Col":        "Officer",
                    "Major":      "Officer",
                    "Jonkheer":   "Royalty",
                    "Don":        "Royalty",
                    "Sir" :       "Royalty",
                    "Dr":         "Officer",
                    "Rev":        "Officer",
                    "the Countess":"Royalty",
                    "Dona":       "Royalty",
                    "Mme":        "Mrs",
                    "Mlle":       "Miss",
                    "Ms":         "Mrs",
                    "Lady" :      "Royalty"}
combined['Title'] = combined['Name'].map(lambda name:name.split(',')[1].split('.')[0].strip())
combined['Title'] = combined.Title.apply(lambda x:Title_Dictionary.get(x,x))

# %%
combined
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked  \
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male   NaN      0      0              359309    8.0500   NaN        S
# 1308    male   NaN      1      1                2668   22.3583   NaN        C
#
#         Title
# 0          Mr
# 1         Mrs
# 2        Miss
# 3         Mrs
# 4          Mr
# ...       ...
# 1304       Mr
# 1305  Royalty
# 1306       Mr
# 1307       Mr
# 1308   Master
#
# [1309 rows x 12 columns]

# %%
# 기존 프로젝트 코드 오류 발생 - median 처리 시 수치형 데이터 이외 값이 포함되어 실행 오류 발생
grouped_median_train = combined.iloc[:len(train)].groupby(['Sex','Pclass','Title']).median()
grouped_median_test = combined.iloc[len(train):].groupby(['Sex','Pclass','Title']).median()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1489             try:
# -> 1490                 result = self.grouper._cython_operation(
#    1491                     "aggregate",
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     958         ngroups = self.ngroups
# --> 959         return cy_op.cython_operation(
#     960             values=values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     656
# --> 657         return self._cython_op_ndim_compat(
#     658             values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     496
# --> 497         return self._call_cython_op(
#     498             values,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, **kwargs)
#     540         out_shape = self._get_output_shape(ngroups, values)
# --> 541         func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
#     542         values = self._get_cython_vals(values)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _get_cython_function(cls, kind, how, dtype, is_numeric)
#     166                 # no fused types -> no __signatures__
# --> 167                 raise NotImplementedError(
#     168                     f"function is not implemented for this dtype: "
#
# NotImplementedError: function is not implemented for this dtype: [how->median,dtype->object]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     785         try:
# --> 786             values = values.astype("f8")
#     787         except ValueError as err:
#
# ValueError: could not convert string to float: 'Bonnell, Miss. Elizabeth'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-0ab36e540ae5> in <cell line: 1>()
# ----> 1 grouped_median_train = combined.iloc[:len(train)].groupby(['Sex','Pclass','Title']).median()
#       2 grouped_median_test = combined.iloc[len(train):].groupby(['Sex','Pclass','Title']).median()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in median(self, numeric_only)
#    1881             Median of values within each group.
#    1882         """
# -> 1883         result = self._cython_agg_general(
#    1884             "median",
#    1885             alt=lambda x: Series(x).median(numeric_only=numeric_only),
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1505             return result
#    1506
# -> 1507         new_mgr = data.grouped_reduce(array_func)
#    1508         res = self._wrap_agged_manager(new_mgr)
#    1509         out = self._wrap_aggregated_output(res)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/managers.py in grouped_reduce(self, func)
#    1501                 #  while others do not.
#    1502                 for sb in blk._split():
# -> 1503                     applied = sb.apply(func)
#    1504                     result_blocks = extend_blocks(applied, result_blocks)
#    1505             else:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/blocks.py in apply(self, func, **kwargs)
#     327         one
#     328         """
# --> 329         result = func(self.values, **kwargs)
#     330
#     331         return self._split_op_result(result)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in array_func(values)
#    1501                 # try to python agg
#    1502                 # TODO: shouldn't min_count matter?
# -> 1503                 result = self._agg_py_fallback(values, ndim=data.ndim, alt=alt)
#    1504
#    1505             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in _agg_py_fallback(self, values, ndim, alt)
#    1455         #  should always be preserved by the implemented aggregations
#    1456         # TODO: Is this exactly right; see WrappedCythonOp get_result_dtype?
# -> 1457         res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1458
#    1459         if isinstance(values, Categorical):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in agg_series(self, obj, func, preserve_dtype)
#     992             preserve_dtype = True
#     993
# --> 994         result = self._aggregate_series_pure_python(obj, func)
#     995
#     996         npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/ops.py in _aggregate_series_pure_python(self, obj, func)
#    1013
#    1014         for i, group in enumerate(splitter):
# -> 1015             res = func(group)
#    1016             res = libreduction.extract_result(res)
#    1017
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/groupby/groupby.py in <lambda>(x)
#    1883         result = self._cython_agg_general(
#    1884             "median",
# -> 1885             alt=lambda x: Series(x).median(numeric_only=numeric_only),
#    1886             numeric_only=numeric_only,
#    1887         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11621             **kwargs,
#   11622         ):
# > 11623             return NDFrame.median(self, axis, skipna, numeric_only, **kwargs)
#   11624
#   11625         setattr(cls, "median", median)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in median(self, axis, skipna, numeric_only, **kwargs)
#   11210         **kwargs,
#   11211     ) -> Series | float:
# > 11212         return self._stat_function(
#   11213             "median", nanops.nanmedian, axis, skipna, numeric_only, **kwargs
#   11214         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11156         validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11157
# > 11158         return self._reduce(
#   11159             func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11160         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in _reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    4668                 )
#    4669             with np.errstate(all="ignore"):
# -> 4670                 return op(delegate, skipna=skipna, **kwds)
#    4671
#    4672     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in f(values, axis, skipna, **kwds)
#     156                     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     157             else:
# --> 158                 result = alt(values, axis=axis, skipna=skipna, **kwds)
#     159
#     160             return result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/nanops.py in nanmedian(values, axis, skipna, mask)
#     787         except ValueError as err:
#     788             # e.g. "could not convert string to float: 'a'"
# --> 789             raise TypeError(str(err)) from err
#     790     if mask is not None:
#     791         values[mask] = np.nan
#
# TypeError: could not convert string to float: 'Bonnell, Miss. Elizabeth'

# %%
# 오류코드 수정

# 숫자형 데이터만을 선택
numeric_data_train = combined.iloc[:len(train)].select_dtypes(include=[np.number])
numeric_data_test = combined.iloc[len(train):].select_dtypes(include=[np.number])

# 이제 숫자형 데이터에 대해서만 그룹화 후 중간값을 계산
grouped_median_train = numeric_data_train.groupby([combined.iloc[:len(train)]['Sex'], combined.iloc[:len(train)]['Pclass'], combined.iloc[:len(train)]['Title']]).median()
grouped_median_test = numeric_data_test.groupby([combined.iloc[len(train):]['Sex'], combined.iloc[len(train):]['Pclass'], combined.iloc[len(train):]['Title']]).median()

# %%
def fillAges(row, grouped_median):
    if np.isnan(row['Age']):
        return grouped_median.loc[row['Sex'], row['Pclass'], row['Title']]['Age']
    else:
        return row['Age']

# %%
# Fills in the missing age in combined based on these different attributes.
combined.iloc[:len(train)]['Age'] = combined.iloc[:len(train)].apply(lambda r : fillAges(r, grouped_median_train), axis=1)
combined.iloc[len(train):]['Age'] = combined.iloc[len(train):].apply(lambda r : fillAges(r, grouped_median_test), axis=1)
# Out:
# <ipython-input-32-b3d6f2db9ca9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined.iloc[:len(train)]['Age'] = combined.iloc[:len(train)].apply(lambda r : fillAges(r, grouped_median_train), axis=1)
# <ipython-input-32-b3d6f2db9ca9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined.iloc[len(train):]['Age'] = combined.iloc[len(train):].apply(lambda r : fillAges(r, grouped_median_test), axis=1)

# %%
combined.drop('Name', axis=1, inplace=True)
le_title = LabelEncoder()
combined['Title'] = le_title.fit_transform(combined['Title'])

# %%
# Fills the fare by the mean
combined.Fare.fillna(combined.Fare.mean(), inplace=True)

# Fills the embarked by the most common
combined.Embarked.fillna('S', inplace=True)

le_embarked = LabelEncoder()
combined['Embarked'] = le_embarked.fit_transform(combined['Embarked'])

# Replacing missing cabins with U (for Uknown)
combined.Cabin.fillna('U', inplace=True)
# mapping each Cabin value with the cabin letter
combined['Cabin'] = combined['Cabin'].map(lambda c : c[0])

le_cabin = LabelEncoder()
combined['Cabin'] = le_cabin.fit_transform(combined['Cabin'])

# Encoder for Sex
le_sex = LabelEncoder()
combined['Sex'] = le_sex.fit_transform(combined['Sex'])

# %%
def cleanTicket(ticket):
    ticket = ticket.replace('.','')
    ticket = ticket.replace('/','')
    ticket = ticket.split()
    ticket = list(map(lambda t : t.strip(), ticket))
    ticket = list(filter(lambda t : not t.isdigit(), ticket))
    if len(ticket) > 0:
        return ticket[0]
    else:
        return 'XXX'

# %%
combined['Ticket'] = combined['Ticket'].apply(cleanTicket)
le_ticket = LabelEncoder()
combined['Ticket'] = le_ticket.fit_transform(combined['Ticket'])

# %%
# Variables around family feature
combined['FamilySize'] = combined['Parch'] + combined['SibSp'] + 1
combined['Singleton'] = combined['FamilySize'].map(lambda s: 1 if s == 1 else 0)
combined['SmallFamily'] = combined['FamilySize'].map(lambda s: 1 if 2<=s<=4 else 0)
combined['LargeFamily'] = combined['FamilySize'].map(lambda s: 1 if 5<=s else 0)

combined.drop('PassengerId', inplace=True, axis=1)

# %%
combined.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Pclass       1309 non-null   int64
#  1   Sex          1309 non-null   int64
#  2   Age          1046 non-null   float64
#  3   SibSp        1309 non-null   int64
#  4   Parch        1309 non-null   int64
#  5   Ticket       1309 non-null   int64
#  6   Fare         1309 non-null   float64
#  7   Cabin        1309 non-null   int64
#  8   Embarked     1309 non-null   int64
#  9   Title        1309 non-null   int64
#  10  FamilySize   1309 non-null   int64
#  11  Singleton    1309 non-null   int64
#  12  SmallFamily  1309 non-null   int64
#  13  LargeFamily  1309 non-null   int64
# dtypes: float64(2), int64(12)
# memory usage: 143.3 KB

# %%
combined = combined.dropna()

# %%
combined
# Out:
#       Pclass  Sex   Age  SibSp  Parch  Ticket      Fare  Cabin  Embarked  \
# 0          3    1  22.0      1      0       2    7.2500      8         2
# 1          1    0  38.0      1      0      14   71.2833      2         0
# 2          3    0  26.0      0      0      31    7.9250      8         2
# 3          1    0  35.0      1      0      36   53.1000      2         2
# 4          3    1  35.0      0      0      36    8.0500      8         2
# ...      ...  ...   ...    ...    ...     ...       ...    ...       ...
# 1300       3    0   3.0      1      1      28   13.7750      8         2
# 1302       1    0  37.0      1      0      36   90.0000      2         1
# 1303       3    0  28.0      0      0      36    7.7750      8         2
# 1305       1    0  39.0      0      0      14  108.9000      2         0
# 1306       3    1  38.5      0      0      28    7.2500      8         2
#
#       Title  FamilySize  Singleton  SmallFamily  LargeFamily
# 0         2           2          0            1            0
# 1         3           2          0            1            0
# 2         1           1          1            0            0
# 3         3           2          0            1            0
# 4         2           1          1            0            0
# ...     ...         ...        ...          ...          ...
# 1300      1           3          0            1            0
# 1302      3           2          0            1            0
# 1303      1           1          1            0            0
# 1305      5           1          1            0            0
# 1306      2           1          1            0            0
#
# [1046 rows x 14 columns]

# %%
df = df.dropna()
df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 10       1   PP 9549  16.7000           G6        S
# 11       0    113783  26.5500         C103        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [202 rows x 12 columns]

# %% [markdown]
# ### Modeling

# %%
X_train = combined.head(len(train))
X_test = combined[len(train):]
y_train = df.Survived

# %%
def compute_score(clf, X, y, scoring='accuracy'):
    xval = cross_val_score(clf, X, y, cv = 5, scoring=scoring)
    return np.mean(xval)

# %%
clf = RandomForestClassifier(n_estimators=50, max_features='sqrt')
clf = clf.fit(X_train, y_train)

# %%
# feat_imp = dict(zip(X_train.columns[np.argsort(clf.feature_importances_)[::-1]],
#     np.sort(clf.feature_importances_)[::-1]))
# new_cols = [k for k,v in feat_imp.items() if v > 0.02]
# train_reduced = X_train[new_cols]
# test_reduced = X_test[new_cols]

model = SelectFromModel(clf, prefit=True)
train_reduced = model.transform(X_train)
test_reduced = model.transform(X_test)
train_reduced.shape, X_train.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but SelectFromModel was fitted without feature names
#   warnings.warn(
# ((891, 3), (891, 14))

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import GridSearchCV

# turn run_gs to True if you want to run the gridsearch again.
run_gs = False

if run_gs:
    parameter_grid = {
                 'max_depth' : [4, 6, 8],
                 'n_estimators': [50, 10],
                 'max_features': ['sqrt', 'auto', 'log2'],
                 'min_samples_split': [2, 3, 10],
                 'min_samples_leaf': [1, 3, 10],
                 'bootstrap': [True, False],
                 }
    forest = RandomForestClassifier()
    cross_validation = StratifiedKFold(y_train, n_folds=5)

    grid_search = GridSearchCV(forest,
                               scoring='accuracy',
                               param_grid=parameter_grid,
                               cv=cross_validation)

    grid_search.fit(train_reduced, y_train)
    model = grid_search
    parameters = grid_search.best_params_

    print('Best score: {}'.format(grid_search.best_score_))
    print('Best parameters: {}'.format(grid_search.best_params_))
else:
    parameters = {'bootstrap': False, 'min_samples_leaf': 3, 'n_estimators': 50,
                  'min_samples_split': 10, 'max_features': 'sqrt', 'max_depth': 6}
    model = RandomForestClassifier(**parameters)
    model.fit(train_reduced, y_train)

# %%
compute_score(model, train_reduced, y_train, scoring='accuracy')
# Out:
# 0.6094344360052728

# %%
df_output
# Out:
#      PassengerId
# 0            892
# 1            893
# 2            894
# 3            895
# 4            896
# ..           ...
# 413         1305
# 414         1306
# 415         1307
# 416         1308
# 417         1309
#
# [418 rows x 1 columns]

# %%
model.score(train_reduced, y_train)
# Out:
# 0.6778900112233446

# %% [markdown]
# # **2. 새로운 모델 건설 및 발전**

# %%
train2 = pd.read_csv('/content/drive/MyDrive/2024_인공지능/팀플_타이타닉/train.csv')
test2 = pd.read_csv('/content/drive/MyDrive/2024_인공지능/팀플_타이타닉/test.csv')
combined2 = pd.concat([train2, test2])
combined2.reset_index(inplace=True)
combined2.drop('index', inplace=True, axis=1)

# %%
train2
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
test2
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0      male  34.5      0      0              330911    7.8292   NaN        Q
# 1    female  47.0      1      0              363272    7.0000   NaN        S
# 2      male  62.0      0      0              240276    9.6875   NaN        Q
# 3      male  27.0      0      0              315154    8.6625   NaN        S
# 4    female  22.0      1      1             3101298   12.2875   NaN        S
# ..      ...   ...    ...    ...                 ...       ...   ...      ...
# 413    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  female  39.0      0      0            PC 17758  108.9000  C105        C
# 415    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416    male   NaN      0      0              359309    8.0500   NaN        S
# 417    male   NaN      1      1                2668   22.3583   NaN        C
#
# [418 rows x 11 columns]

# %%
combined2
# Out:
#       PassengerId  Pclass                                               Name  \
# 0               1       3                            Braund, Mr. Owen Harris
# 1               2       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2               3       3                             Heikkinen, Miss. Laina
# 3               4       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4               5       3                           Allen, Mr. William Henry
# ...           ...     ...                                                ...
# 1304         1305       3                                 Spector, Mr. Woolf
# 1305         1306       1                       Oliva y Ocana, Dona. Fermina
# 1306         1307       3                       Saether, Mr. Simon Sivertsen
# 1307         1308       3                                Ware, Mr. Frederick
# 1308         1309       3                           Peter, Master. Michael J
#
#          Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 0       male  22.0      1      0           A/5 21171    7.2500   NaN        S
# 1     female  38.0      1      0            PC 17599   71.2833   C85        C
# 2     female  26.0      0      0    STON/O2. 3101282    7.9250   NaN        S
# 3     female  35.0      1      0              113803   53.1000  C123        S
# 4       male  35.0      0      0              373450    8.0500   NaN        S
# ...      ...   ...    ...    ...                 ...       ...   ...      ...
# 1304    male   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 1305  female  39.0      0      0            PC 17758  108.9000  C105        C
# 1306    male  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1307    male   NaN      0      0              359309    8.0500   NaN        S
# 1308    male   NaN      1      1                2668   22.3583   NaN        C
#
# [1309 rows x 11 columns]

# %%
combined2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Pclass       1309 non-null   int64
#  2   Name         1309 non-null   object
#  3   Sex          1309 non-null   object
#  4   Age          1046 non-null   float64
#  5   SibSp        1309 non-null   int64
#  6   Parch        1309 non-null   int64
#  7   Ticket       1309 non-null   object
#  8   Fare         1308 non-null   float64
#  9   Cabin        295 non-null    object
#  10  Embarked     1307 non-null   object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 112.6+ KB

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Fills the fare by the mean
train2.Fare.fillna(train2.Fare.mean(), inplace=True)

# Fills the embarked by the most common
train2.Embarked.fillna('S', inplace=True)

le_embarked = LabelEncoder()
train2['Embarked'] = le_embarked.fit_transform(train2['Embarked'])

# Replacing missing cabins with U (for Uknown)
train2.Cabin.fillna('U', inplace=True)
# mapping each Cabin value with the cabin letter
train2['Cabin'] = train2['Cabin'].map(lambda c : c[0])

le_cabin = LabelEncoder()
train2['Cabin'] = le_cabin.fit_transform(train2['Cabin'])

# Encoder for Sex
le_sex = LabelEncoder()
train2['Sex'] = le_sex.fit_transform(train2['Sex'])

# %%
train2['Ticket'] = train2['Ticket'].apply(cleanTicket)
le_ticket = LabelEncoder()
train2['Ticket'] = le_ticket.fit_transform(train2['Ticket'])

# %%
# Variables around family feature
train2['FamilySize'] = train2['Parch'] + train2['SibSp'] + 1
train2['Singleton'] = train2['FamilySize'].map(lambda s: 1 if s == 1 else 0)
train2['SmallFamily'] = train2['FamilySize'].map(lambda s: 1 if 2<=s<=4 else 0)
train2['LargeFamily'] = train2['FamilySize'].map(lambda s: 1 if 5<=s else 0)

train2.drop('PassengerId', inplace=True, axis=1)

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Survived     891 non-null    int64
#  1   Pclass       891 non-null    int64
#  2   Name         891 non-null    object
#  3   Sex          891 non-null    int64
#  4   Age          714 non-null    float64
#  5   SibSp        891 non-null    int64
#  6   Parch        891 non-null    int64
#  7   Ticket       891 non-null    int64
#  8   Fare         891 non-null    float64
#  9   Cabin        891 non-null    int64
#  10  Embarked     891 non-null    int64
#  11  FamilySize   891 non-null    int64
#  12  Singleton    891 non-null    int64
#  13  SmallFamily  891 non-null    int64
#  14  LargeFamily  891 non-null    int64
# dtypes: float64(2), int64(12), object(1)
# memory usage: 104.5+ KB

# %%
train2_dropna = train2.dropna()
train2_dropna
# Out:
#      Survived  Pclass                                               Name  Sex  \
# 0           0       3                            Braund, Mr. Owen Harris    1
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0
# 2           1       3                             Heikkinen, Miss. Laina    0
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0
# 4           0       3                           Allen, Mr. William Henry    1
# ..        ...     ...                                                ...  ...
# 885         0       3               Rice, Mrs. William (Margaret Norton)    0
# 886         0       2                              Montvila, Rev. Juozas    1
# 887         1       1                       Graham, Miss. Margaret Edith    0
# 889         1       1                              Behr, Mr. Karl Howell    1
# 890         0       3                                Dooley, Mr. Patrick    1
#
#       Age  SibSp  Parch  Ticket     Fare  Cabin  Embarked  FamilySize  \
# 0    22.0      1      0       1   7.2500      8         2           2
# 1    38.0      1      0      10  71.2833      2         0           2
# 2    26.0      0      0      26   7.9250      8         2           1
# 3    35.0      1      0      30  53.1000      2         2           2
# 4    35.0      0      0      30   8.0500      8         2           1
# ..    ...    ...    ...     ...      ...    ...       ...         ...
# 885  39.0      0      5      30  29.1250      8         1           6
# 886  27.0      0      0      30  13.0000      8         2           1
# 887  19.0      0      0      30  30.0000      1         2           1
# 889  26.0      0      0      30  30.0000      2         0           1
# 890  32.0      0      0      30   7.7500      8         1           1
#
#      Singleton  SmallFamily  LargeFamily
# 0            0            1            0
# 1            0            1            0
# 2            1            0            0
# 3            0            1            0
# 4            1            0            0
# ..         ...          ...          ...
# 885          0            0            1
# 886          1            0            0
# 887          1            0            0
# 889          1            0            0
# 890          1            0            0
#
# [714 rows x 15 columns]

# %%
train2_drop = train2_dropna.drop(['Name'], axis=1)
train2_drop
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch  Ticket     Fare  Cabin  \
# 0           0       3    1  22.0      1      0       1   7.2500      8
# 1           1       1    0  38.0      1      0      10  71.2833      2
# 2           1       3    0  26.0      0      0      26   7.9250      8
# 3           1       1    0  35.0      1      0      30  53.1000      2
# 4           0       3    1  35.0      0      0      30   8.0500      8
# ..        ...     ...  ...   ...    ...    ...     ...      ...    ...
# 885         0       3    0  39.0      0      5      30  29.1250      8
# 886         0       2    1  27.0      0      0      30  13.0000      8
# 887         1       1    0  19.0      0      0      30  30.0000      1
# 889         1       1    1  26.0      0      0      30  30.0000      2
# 890         0       3    1  32.0      0      0      30   7.7500      8
#
#      Embarked  FamilySize  Singleton  SmallFamily  LargeFamily
# 0           2           2          0            1            0
# 1           0           2          0            1            0
# 2           2           1          1            0            0
# 3           2           2          0            1            0
# 4           2           1          1            0            0
# ..        ...         ...        ...          ...          ...
# 885         1           6          0            0            1
# 886         2           1          1            0            0
# 887         2           1          1            0            0
# 889         0           1          1            0            0
# 890         1           1          1            0            0
#
# [714 rows x 14 columns]

# %%
# x feature, 예측 변수 y 정의
x_df=train2_drop.loc[:,['Pclass','Sex','Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked','FamilySize','Singleton','SmallFamily','LargeFamily']]
y_df=train2_drop['Survived']

# train/test set으로 나누기
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_df, y_df, test_size=0.2, random_state=42)

# %% [markdown]
# - XGBClassifier 모델 건설

# %%
from xgboost import XGBClassifier
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import SelectFromModel
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split


# NaN 값을 평균으로 대체
imputer = SimpleImputer(strategy='mean')
X_train_imputed = imputer.fit_transform(X_train)
X_test_imputed = imputer.transform(X_test)

# XGBoost 모델 학습
clf = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=6)
clf.fit(X_train_imputed, y_train)

# 중요 특징 선택
model = SelectFromModel(clf, prefit=True)
X_train_reduced = model.transform(X_train_imputed)
X_test_reduced = model.transform(X_test_imputed)

# 선택된 특징을 사용하여 모델 재학습
clf_reduced = XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=6)
clf_reduced.fit(X_train_reduced, y_train)

# 테스트 데이터에 대한 예측 수행
y_pred = clf_reduced.predict(X_test_reduced)

# 정확도 평가
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.4f}')

# 선택된 특징의 개수와 원래 특징의 개수 출력
print(f'Reduced features shape: {X_train_reduced.shape}, Original features shape: {X_train.shape}')
# Out:
# Accuracy: 0.7972
# Reduced features shape: (571, 3), Original features shape: (571, 13)

# %% [markdown]
# - LGBM 모델 건설

# %%
# 비선형 모델인 lightGBM 예측 모델
from lightgbm import LGBMRegressor
from sklearn.metrics import r2_score
import joblib

# LGBM 모델 건설
lgbm=LGBMRegressor()
lgbm.fit(X_train, y_train)
pred= lgbm.predict(X_test)

#성능 확인
print("R2",r2_score(y_test,pred))
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000422 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 233
# [LightGBM] [Info] Number of data points in the train set: 571, number of used features: 13
# [LightGBM] [Info] Start training from score 0.409807
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# R2 0.3478234194480544

# %% [markdown]
# - 그라디언트 부스팅 모델 건설

# %%
from sklearn.ensemble import GradientBoostingClassifier

# 그라디언트 부스팅 모델 초기화
gb_model = GradientBoostingClassifier()

# 모델 학습
gb_model.fit(X_train, y_train)

# 모델 평가
gb_accuracy = gb_model.score(X_test, y_test)
print("Gradient Boosting Accuracy:", gb_accuracy)
# Out:
# Gradient Boosting Accuracy: 0.8041958041958042

# %%
# 모델튜닝 : 모델의 하이퍼파라미터 조정

from sklearn.model_selection import GridSearchCV

# 그리드 서치를 위한 하이퍼파라미터 그리드 설정
param_grid = {'n_estimators': [100, 200, 300],
              'learning_rate': [0.1, 0.05, 0.01]}

# 그리드 서치 수행
grid_search = GridSearchCV(GradientBoostingClassifier(), param_grid, cv=5)
grid_search.fit(X_train, y_train)

# 최적의 하이퍼파라미터 출력
print("Best Hyperparameters:", grid_search.best_params_)

# 최적의 모델로 평가
best_model = grid_search.best_estimator_
best_accuracy = best_model.score(X_test, y_test)
print("Best Model Accuracy:", best_accuracy)
# Out:
# Best Hyperparameters: {'learning_rate': 0.05, 'n_estimators': 200}
# Best Model Accuracy: 0.8111888111888111

# %%
# 교차 검증

from sklearn.model_selection import cross_val_score

# 교차 검증 수행
cv_scores = cross_val_score(gb_model, X_train, y_train, cv=5)

# 교차 검증 평균 정확도 출력
print("Cross-Validation Mean Accuracy:", cv_scores.mean())
# Out:
# Cross-Validation Mean Accuracy: 0.8231273836765828

# %%
from sklearn.ensemble import VotingClassifier

# 다른 모델 초기화 (예: 랜덤 포레스트)
rf_model = RandomForestClassifier()

# 앙상블 모델 초기화
voting_model = VotingClassifier(estimators=[('gb', gb_model), ('rf', rf_model)])

# 앙상블 모델 학습
voting_model.fit(X_train, y_train)

# 앙상블 모델 평가
voting_accuracy = voting_model.score(X_test, y_test)
print("Voting Model Accuracy:", voting_accuracy)
# Out:
# Voting Model Accuracy: 0.7902097902097902

# %% [markdown]
# # **3. 딥러닝 적용**

# %%
from sklearn.preprocessing import StandardScaler, LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.utils import to_categorical


# 데이터 표준화
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# MLP 모델 구축
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 학습
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 18ms/step - loss: 0.7383 - accuracy: 0.5526 - val_loss: 0.6292 - val_accuracy: 0.6348
# Epoch 2/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.6536 - accuracy: 0.6272 - val_loss: 0.5930 - val_accuracy: 0.6870
# Epoch 3/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.6510 - accuracy: 0.6491 - val_loss: 0.5728 - val_accuracy: 0.6870
# Epoch 4/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.5983 - accuracy: 0.6930 - val_loss: 0.5582 - val_accuracy: 0.7043
# Epoch 5/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.5889 - accuracy: 0.7039 - val_loss: 0.5434 - val_accuracy: 0.7043
# Epoch 6/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0
# %%
# 모델 평가
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test Accuracy: 0.8182

# %%
import matplotlib.pyplot as plt

# 학습 과정 시각화
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# MLP 모델 구축
model = Sequential()
model.add(Dense(64, input_dim=X_train.shape[1], activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))  # 새로운 은닉층 추가
model.add(Dropout(0.5))
model.add(Dense(32, activation='tanh'))  # 활성화 함수 변경
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# 모델 컴파일 (다양한 최적화 알고리즘 사용)
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # RMSprop 최적화 알고리즘 사용

# 모델 학습
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 2s 30ms/step - loss: 0.7841 - accuracy: 0.5197 - val_loss: 0.6684 - val_accuracy: 0.6348
# Epoch 2/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.7223 - accuracy: 0.5351 - val_loss: 0.6220 - val_accuracy: 0.6870
# Epoch 3/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.6716 - accuracy: 0.6140 - val_loss: 0.5887 - val_accuracy: 0.7130
# Epoch 4/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6323 - accuracy: 0.6469 - val_loss: 0.5675 - val_accuracy: 0.7217
# Epoch 5/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.6555 - accuracy: 0.6579 - val_loss: 0.5500 - val_accuracy: 0.7217
# Epoch 6/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.6262 - accuracy: 0.6689 - val_loss: 0.5368 - val_accuracy: 0.7130
# Epoch 7/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5664 - accuracy: 0.7456 - val_loss: 0.5169 - val_accuracy: 0.7391
# Epoch 8/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5758 - accuracy: 0.7412 - val_loss: 0.5045 - val_accuracy: 0.7217
# Epoch 9/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.5220 - accuracy: 0.7675 - val_loss: 0.4979 - val_accuracy: 0.7304
# Epoch 10/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.5330 - accuracy: 0.7478 - val_loss: 0.4940 - val_accuracy: 0.7478
# Epoch 11/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.5179 - accuracy: 0.7544 - val_loss: 0.4841 - val_accuracy: 0.7565
# Epoch 12/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5254 - accuracy: 0.7566 - val_loss: 0.4767 - val_accuracy: 0.7739
# Epoch 13/100
# 15/15 [==============================] - 0s 8ms/step - loss: 0.5132 - accuracy: 0.7675 - val_loss: 0.4689 - val_accuracy: 0.7913
# Epoch 14/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4765 - accuracy: 0.7873 - val_loss: 0.4638 - val_accuracy: 0.8000
# Epoch 15/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4969 - accuracy: 0.7939 - val_loss: 0.4679 - val_accuracy: 0.7913
# Epoch 16/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4961 - accuracy: 0.7917 - val_loss: 0.4689 - val_accuracy: 0.8087
# Epoch 17/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4938 - accuracy: 0.7982 - val_loss: 0.4615 - val_accuracy: 0.8087
# Epoch 18/100
# 15/15 [==============================] - 0s 10ms/step - loss: 0.4957 - accuracy: 0.7961 - val_loss: 0.4632 - val_accuracy: 0.8087
# Epoch 19/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.4882 - accuracy: 0.7895 - val_loss: 0.4659 - val_accuracy: 0.8087
# Epoch 20/100
# 15/15 [==============================] - 0s 9ms/step - loss: 0.5010 - accuracy: 0.7851 - val_loss: 0.4604 - val_accuracy: 0.8000
# Epoch 21/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.4859 - accuracy: 0.7982 - val_loss: 0.4632 - val_accuracy: 0.8087
# Epoch 22/100
# 15/15 [==============================] - 0s 21ms/step - loss: 0.4876 - accuracy: 0.7982 - val_loss: 0.4630 - val_accuracy: 0.8000
# Epoch 23/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4548 - accuracy: 0.8092 - val_loss: 0.4649 - val_accuracy: 0.8000
# Epoch 24/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4771 - accuracy: 0.8070 - val_loss: 0.4606 - val_accuracy: 0.8000
# Epoch 25/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.
100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.4127 - accuracy: 0.8202 - val_loss: 0.4504 - val_accuracy: 0.8174
# Epoch 89/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3944 - accuracy: 0.8399 - val_loss: 0.4477 - val_accuracy: 0.8174
# Epoch 90/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3816 - accuracy: 0.8509 - val_loss: 0.4494 - val_accuracy: 0.8174
# Epoch 91/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3747 - accuracy: 0.8553 - val_loss: 0.4468 - val_accuracy: 0.8261
# Epoch 92/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3787 - accuracy: 0.8596 - val_loss: 0.4540 - val_accuracy: 0.8261
# Epoch 93/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3759 - accuracy: 0.8421 - val_loss: 0.4525 - val_accuracy: 0.8348
# Epoch 94/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3902 - accuracy: 0.8465 - val_loss: 0.4550 - val_accuracy: 0.8261
# Epoch 95/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3861 - accuracy: 0.8443 - val_loss: 0.4554 - val_accuracy: 0.8000
# Epoch 96/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3618 - accuracy: 0.8596 - val_loss: 0.4583 - val_accuracy: 0.8000
# Epoch 97/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3908 - accuracy: 0.8399 - val_loss: 0.4606 - val_accuracy: 0.8000
# Epoch 98/100
# 15/15 [==============================] - 0s 5ms/step - loss: 0.3753 - accuracy: 0.8399 - val_loss: 0.4633 - val_accuracy: 0.8000
# Epoch 99/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.4032 - accuracy: 0.8596 - val_loss: 0.4645 - val_accuracy: 0.8000
# Epoch 100/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3559 - accuracy: 0.8596 - val_loss: 0.4714 - val_accuracy: 0.7913

# %%
# 모델 평가
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test Accuracy: 0.8042

# %%
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))  # 첫 번째 은닉층
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))  # 두 번째 은닉층
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))  # 세 번째 은닉층
model.add(Dropout(0.5))
model.add(Dense(32, activation='tanh'))  # 네 번째 은닉층
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))


# 모델 컴파일 (다양한 최적화 알고리즘 사용)
model.compile(loss='binary_crossentropy', optimizer='RMSprop', metrics=['accuracy'])  # RMSprop 최적화 알고리즘 사용

# 모델 학습
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 15/15 [==============================] - 4s 57ms/step - loss: 0.7709 - accuracy: 0.5417 - val_loss: 0.6336 - val_accuracy: 0.6783
# Epoch 2/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.6773 - accuracy: 0.5899 - val_loss: 0.5972 - val_accuracy: 0.6870
# Epoch 3/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6460 - accuracy: 0.6579 - val_loss: 0.5574 - val_accuracy: 0.7391
# Epoch 4/100
# 15/15 [==============================] - 0s 20ms/step - loss: 0.6224 - accuracy: 0.6601 - val_loss: 0.5318 - val_accuracy: 0.7478
# Epoch 5/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.6013 - accuracy: 0.7149 - val_loss: 0.5053 - val_accuracy: 0.7565
# Epoch 6/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.5933 - accuracy: 0.7193 - val_loss: 0.4867 - val_accuracy: 0.7739
# Epoch 7/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5496 - accuracy: 0.7325 - val_loss: 0.4796 - val_accuracy: 0.7478
# Epoch 8/100
# 15/15 [==============================] - 0s 14ms/step - loss: 0.5657 - accuracy: 0.7412 - val_loss: 0.4649 - val_accuracy: 0.7478
# Epoch 9/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.5482 - accuracy: 0.7829 - val_loss: 0.4577 - val_accuracy: 0.7565
# Epoch 10/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0
100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8596 - val_loss: 0.4759 - val_accuracy: 0.8000
# Epoch 98/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3538 - accuracy: 0.8706 - val_loss: 0.4764 - val_accuracy: 0.8174
# Epoch 99/100
# 15/15 [==============================] - 0s 6ms/step - loss: 0.3770 - accuracy: 0.8684 - val_loss: 0.4681 - val_accuracy: 0.8174
# Epoch 100/100
# 15/15 [==============================] - 0s 7ms/step - loss: 0.3738 - accuracy: 0.8596 - val_loss: 0.4619 - val_accuracy: 0.8174

# %%
# 모델 평가
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'Test Accuracy: {accuracy:.4f}')
# Out:
# Test Accuracy: 0.8042

# %%
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, GRU, Embedding, Dropout

# %%
# 모델 빌드
model = Sequential()
model.add(LSTM(64, input_shape=(X_train.shape[1], 1)))  # LSTM 레이어 추가
# 또는 model.add(GRU(64, input_shape=(X_train.shape[1], 1)))  # GRU 레이어 추가
model.add(Dropout(0.5))  # 드롭아웃 레이어 추가
model.add(Dense(1, activation='sigmoid'))  # 출력 레이어 추가

# %%
# 모델 컴파일
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 모델 학습
model.fit(X_train.reshape(X_train.shape[0], X_train.shape[1], 1), y_train, epochs=100, batch_size=32, validation_split=0.2)

# 모델 평가
loss, accuracy = model.evaluate(X_test.reshape(X_test.shape[0], X_test.shape[1], 1), y_test)
print(f'Test Accuracy: {accuracy}')
# Out:
# Epoch 1/100
# 15/15 [==============================] - 7s 144ms/step - loss: 0.6806 - accuracy: 0.6294 - val_loss: 0.6645 - val_accuracy: 0.6435
# Epoch 2/100
# 15/15 [==============================] - 0s 23ms/step - loss: 0.6269 - accuracy: 0.6754 - val_loss: 0.5804 - val_accuracy: 0.6957
# Epoch 3/100
# 15/15 [==============================] - 0s 24ms/step - loss: 0.5445 - accuracy: 0.7478 - val_loss: 0.5086 - val_accuracy: 0.7652
# Epoch 4/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.4949 - accuracy: 0.7675 - val_loss: 0.4901 - val_accuracy: 0.8000
# Epoch 5/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4784 - accuracy: 0.7939 - val_loss: 0.4742 - val_accuracy: 0.7913
# Epoch 6/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4627 - accuracy: 0.7829 - val_loss: 0.4749 - val_accuracy: 0.7913
# Epoch 7/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4682 - accuracy: 0.8004 - val_loss: 0.4722 - val_accuracy: 0.8000
# Epoch 8/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4460 - accuracy: 0.8070 - val_loss: 0.4693 - val_accuracy: 0.8087
# Epoch 9/100
# 15/15 [==============================] - 0s 11ms/step - loss: 0.4488 - accuracy: 0.8004 - val_loss: 0.4658 - val_accuracy: 0.8087
# Epoch 10/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4546 - accuracy: 0.7982 - val_loss: 0.4792 - val_accuracy: 0.8087
# Epoch 11/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4575 - accuracy: 0.7895 - val_loss: 0.4965 - val_accuracy: 0.7739
# Epoch 12/100
# 15/15 [==============================] - 0s 13ms/step - loss: 0.4659 - accuracy: 0.7851 - val_loss: 0.4673 - val_accuracy: 0.8087
# Epoch 13/100
# 15/15 [==============================] - 0s 12ms/step - loss: 0.4384 - accuracy: 0.8136 - val_loss: 0.4796 - val_accuracy: 0.8000
# Epoch 14/100
# 15/15 [==============================] - 0s 18ms/step - loss: 0.4373 - accuracy: 0.8004 - val_loss: 0.4785 - val_accuracy: 0.8087
# Epoch 15/100
# 15/15 [==============================] - 0s 17ms/step - loss: 0.4392 - accuracy: 0.8048 - val_loss: 0.4767 - val_accuracy: 0.8087
# Epoch 16/100
# 15/15 [==============================] - 0s 16ms/step - loss: 0.
model.add(LSTM(64, return_sequences=False))  # 두 번째 LSTM 층
model.add(Dropout(0.5))  # 드롭아웃 레이어 추가
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])


# 모델 학습
model.fit(X_train.reshape(X_train.shape[0], X_train.shape[1], 1), y_train, epochs=100, batch_size=32, validation_split=0.2)

# 모델 평가
loss, accuracy = model.evaluate(X_test.reshape(X_test.shape[0], X_test.shape[1], 1), y_test)
print(f'Test Accuracy: {accuracy}')
# Out:
# Epoch 1/100
# 15/15 [==============================] - 22s 263ms/step - loss: 0.6444 - accuracy: 0.6820 - val_loss: 0.5326 - val_accuracy: 0.7304
# Epoch 2/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.5129 - accuracy: 0.7719 - val_loss: 0.4769 - val_accuracy: 0.8087
# Epoch 3/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.4903 - accuracy: 0.7873 - val_loss: 0.4701 - val_accuracy: 0.7826
# Epoch 4/100
# 15/15 [==============================] - 0s 34ms/step - loss: 0.4757 - accuracy: 0.8004 - val_loss: 0.4776 - val_accuracy: 0.8000
# Epoch 5/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.4674 - accuracy: 0.8048 - val_loss: 0.4673 - val_accuracy: 0.8174
# Epoch 6/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.4565 - accuracy: 0.8092 - val_loss: 0.4998 - val_accuracy: 0.7565
# Epoch 7/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.4563 - accuracy: 0.8048 - val_loss: 0.4804 - val_accuracy: 0.8000
# Epoch 8/100
# 15/15 [==============================] - 1s 34ms/step - loss: 0.4439 - accuracy: 0.8136 - val_loss: 0.4702 - val_accuracy: 0.7913
# Epoch 9/100
# 15/15 [==============================] - 1s 54ms/step - loss: 0.4512 - accuracy: 0.8070 - val_loss: 0.5184 - val_accuracy: 0.7304
# Epoch 10/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.4525 - accuracy: 0.8136 - val_loss: 0.4759 - val_accuracy: 0.7913
# Epoch 11/100
# 15/15 [==============================] - 1s 58ms/step - loss: 0.4578 - accuracy: 0.8048 - val_loss: 0.4777 - val_accuracy: 0.7913
# Epoch 12/100
# 15/15 [==============================] - 1s 56ms/step - loss: 0.4395 - accuracy: 0.8092 - val_loss: 0.5061 - val_accuracy: 0.7565
# Epoch 13/100
# 15/15 [==============================] - 1s 57ms/step - loss: 0.4316 - accuracy: 0.8158 - val_loss: 0.4811 - val_accuracy: 0.7826
# Epoch 14/100
# 15/15 [==============================] - 1s 58ms/step - loss: 0.4589 - accuracy: 0.7939 - val_loss: 0.4884 - val_accuracy: 0.7739
# Epoch 15/100
# 15/15 [==============================] - 1s 51ms/step - loss: 0.4547 - accuracy: 0.8004 - val_loss: 0.4942 - val_accuracy: 0.7652
# Epoch 16/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.4489 - accuracy: 0.8114 - val_loss: 0.4774 - val_accuracy: 0.7913
# Epoch 17/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.4465 - accuracy: 0.8092 - val_loss: 0.4932 - val_accuracy: 0.7739
# Epoch 18/100
# 15/15 [==============================] - 0s 34ms/step - loss: 0.4398 - accuracy: 0.7982 - val_loss: 0.4823 - val_accuracy: 0.7913
# Epoch 19/100
# 15/15 [==============================] - 0s 33ms/step - loss: 0.4452 - accuracy: 0.8026 - val_loss: 0.4814 - val_accuracy: 0.8000
# Epoch 20/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.4380 - accuracy: 0.8136 - val_loss: 0.4870 - val_accuracy: 0.7826
# Epoch 21/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.4398 - accuracy: 0.8048 - val_loss: 0.4875 - val_accuracy: 0.7826
# Epoch 22/100
# 15/15 [==============================] - 0s 32ms/step - loss: 0.4287 - accuracy: 0.8136 - val_loss: 0.5140 - val_accuracy: 0.7391
# Epoch 23/100
# 15/15 [==============================] - 1s 35ms/step - loss: 0.